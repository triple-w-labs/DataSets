# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
url = "https://raw.githubusercontent.com/triple-w-labs/DataSets/refs/heads/main/business_data.csv"
df = pd.read_csv(url)

X = df[["Advertising_Spend"]] #transforma al vector a 2 dimensiones
Y = df["Sales"]
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=1)

# %% [markdown]
# ## Entrenar Modelo

# %%
model = LinearRegression()
model.fit(X_train, y_train)

Y_Predict = model.predict(X_test)

# %% [markdown]
# ## Graficar Predicciones

# %%
plt.figure(figsize=(8,5))
plt.scatter(X, Y, color='blue', label='Datos reales')
plt.plot(X, model.predict(X), color='red', linewidth=2, label='Línea de regresión')
plt.title('Regresión Lineal Simple: Ventas')
plt.xlabel('Advertising Spend')
plt.ylabel('Ventas')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Evaluar modelo

# %%
r2 = r2_score(y_test, Y_Predict)
mse = mean_squared_error(y_test, Y_Predict)
rmse = np.sqrt(mse)
r = np.corrcoef(X.values.flatten(), Y.values)[0, 1]
print("\n=== RESULTADOS DEL MODELO ===")
print(f"b_0: {model.coef_[0]:.4f}")
print(f"b_1: {model.intercept_:.4f}")
print(f"R²: {r2:.4f}")
print(f"Coeficiente de correlación (r): {r:.4f}")
print(f"Raíz del error cuadrático medio (RMSE): {rmse:.4f}")
# Out:
# === RESULTADOS DEL MODELO ===
# b_0: 3.0107
# b_1: -46.4379
# R²: 0.9952
# Coeficiente de correlación (r): 0.9971
# Raíz del error cuadrático medio (RMSE): 245.0259

# %% [markdown]
# ## Analisis de Resultados

# %%
## R^2 = 0.9952
Esto dice que los datos de Ventas estan muy ligados a la variable de Ventas Totales.
